# %%
import os
import base64
from pymongo import MongoClient
from faker import Faker

# MongoDB connection
client = MongoClient('mongodb://localhost:27017/')
db = client['AI-RECRUITMENT']
collection = db['CANDIDATES']

# Initialize Faker
fake = Faker()

# Function to encode DOCX file to base64
def encode_docx_to_base64(docx_path):
    with open(docx_path, "rb") as docx_file:
        encoded_string = base64.b64encode(docx_file.read()).decode('utf-8')
    return encoded_string

# Path to the directory containing the DOCX files
docx_directory = '/Users/sakshigupta/Downloads/Resumes'

# Iterate over all DOCX files in the directory
for docx_file in os.listdir(docx_directory):
    if docx_file.endswith('.docx'):
        docx_path = os.path.join(docx_directory, docx_file)
        encoded_docx = encode_docx_to_base64(docx_path)
        
        # Generate fake data for additional fields
        candidate_name = fake.name()
        candidate_id = fake.numerify(text="####")
        email = candidate_name.lower().replace(" ", ".") + "@gmail.com"
        phone_number = fake.numerify(text="##########")
        address = fake.address()
        experience = fake.numerify(text="#") + ' year(s)'
        
        # Prepare the document for MongoDB
        document = {
            "id": candidate_id,
            "name": candidate_name,
            "email": email,
            "phone_number": phone_number,
            "address": address,
            "experience": experience,
            "resume": encoded_docx,
            "cover_letter": encoded_docx
        }
        
        # Insert the document into MongoDB
        collection.insert_one(document)
        print(f"Inserted {candidate_name}'s resume into MongoDB with additional fields")

print("All DOCX files have been processed and inserted into MongoDB with additional fields.")

# %%
import os
import base64
import pandas as pd
from pymongo import MongoClient
from faker import Faker
import random
from bs4 import BeautifulSoup

# MongoDB connection
client = MongoClient('mongodb://localhost:27017/')
db = client['AI-RECRUITMENT']
collection = db['CANDIDATES']
db.drop_collection(collection)

# Initialize Faker
fake = Faker()

# Load the dataset
file_path = '/Users/sakshigupta/Downloads/Resume.csv'  # Update this to the correct path if necessary
df = pd.read_csv(file_path)

# Function to generate a synthetic cover letter
def generate_cover_letter(candidate_name, experience, skills, relevant_field):
    technical_skills = ", ".join(skills)
    sentences = [
        f"My name is {candidate_name}, and I am passionate about {relevant_field}.",
        f"With {experience} of experience, I have honed my skills in {technical_skills}.",
        f"I excel at {fake.bs()} and {fake.bs()}, which I believe are critical for this role.",
        f"I am known for my {fake.bs()} and my ability to {fake.bs()} under pressure.",
        f"I look forward to bringing my unique blend of skills and experience to your esteemed company.",
        f"Thank you for considering my application. I am excited about the possibility of contributing to your team."
    ]
    random.shuffle(sentences)
    cover_letter = "\n".join(sentences)
    return cover_letter

# Function to insert the name into HTML resume
def insert_name_in_html(html_str, name):
    soup = BeautifulSoup(html_str, 'html.parser')
    name_tag = soup.new_tag("h1")
    name_tag.string = name
    if soup.body:
        soup.body.insert(0, name_tag)
    else:
        soup.insert(0, name_tag)
    return str(soup)

# Iterate over the dataset
for index, row in df.iterrows():
    resume_id = row['ID']
    resume_str = row['Resume_str']
    resume_html = row['Resume_html']
    category = row['Category']
    
    candidate_name = fake.name()
    email = candidate_name.lower().replace(" ", ".") + "@gmail.com"
    phone_number = fake.numerify(text="##########")
    address = fake.address()
    experience = fake.numerify(text="#") + ' year(s)'
    skills = [fake.job() for _ in range(3)]
    relevant_field = category  # Assuming category is the relevant field

    # Generate a synthetic cover letter
    cover_letter = generate_cover_letter(candidate_name, experience, skills, relevant_field)
    encoded_cover_letter = base64.b64encode(cover_letter.encode('utf-8')).decode('utf-8')

    # Insert the candidate's name into the HTML resume
    updated_resume_html = insert_name_in_html(resume_html, candidate_name)
    
    # Prepare the document for MongoDB
    document = {
        "id": resume_id,
        "name": candidate_name,
        "email": email,
        "phone_number": phone_number,
        "address": address,
        "experience": experience,
        "category": category,
        "resume_str": resume_str,
        "resume_html": updated_resume_html,
        "cover_letter": encoded_cover_letter
    }
    
    # Insert the document into MongoDB
    collection.insert_one(document)
    print(f"Inserted {candidate_name}'s resume into MongoDB with additional fields")

print("All resumes have been processed and inserted into MongoDB with additional fields.")
# Out:
# Inserted Gabriel Wright's resume into MongoDB with additional fields
# Inserted Edward Santana's resume into MongoDB with additional fields
# Inserted Erik Mason's resume into MongoDB with additional fields
# Inserted Deborah Bishop's resume into MongoDB with additional fields
# Inserted Gregory Rogers's resume into MongoDB with additional fields
# Inserted Philip Miller's resume into MongoDB with additional fields
# Inserted Melissa Garrett's resume into MongoDB with additional fields
# Inserted Robert Thompson's resume into MongoDB with additional fields
# Inserted Shelby Johns's resume into MongoDB with additional fields
# Inserted Kent Garza's resume into MongoDB with additional fields
# Inserted Robert Davis's resume into MongoDB with additional fields
# Inserted Jeremy Jensen's resume into MongoDB with additional fields
# Inserted Jessica Flores's resume into MongoDB with additional fields
# Inserted James Cooper's resume into MongoDB with additional fields
# Inserted Michele Stevenson's resume into MongoDB with additional fields
# Inserted Todd Juarez's resume into MongoDB with additional fields
# Inserted Dalton Klein's resume into MongoDB with additional fields
# Inserted Nathan Austin's resume into MongoDB with additional fields
# Inserted Carol Stephens's resume into MongoDB with additional fields
# Inserted Samantha Garcia's resume into MongoDB with additional fields
# Inserted Christine Sanchez's resume into MongoDB with additional fields
# Inserted Shannon Garcia's resume into MongoDB with additional fields
# Inserted Martin Dixon's resume into MongoDB with additional fields
# Inserted Michelle Davis's resume into MongoDB with additional fields
# Inserted Amanda Compton's resume into MongoDB with additional fields
# Inserted Melissa Bennett's resume into MongoDB with additional fields
# Inserted Kathleen Flores's resume into MongoDB with additional fields
# Inserted Terry Murphy's resume into MongoDB with additional fields
# Inserted Todd Scott's resume into MongoDB with additional fields
# Inserted Meghan Garcia's resume into MongoDB with additional fields
# Inserted Veronica Jackson DDS's resume into MongoDB with additional fields
# Inserted Linda Flowers's resume into MongoDB with additional fields
# Inserted James Gutierrez's resume into MongoDB with additional fields
# Inserted Susan Young's resume into MongoDB with additional fields
# Inserted Emily Williams's resume into MongoDB with additional fields
# Inserted Jennifer Walters's resume into MongoDB with additional fields
# Inserted Stephanie King's resume into MongoDB with additional fields
# Inserted Austin Sanchez's resume into MongoDB with additional fields
# Inserted Holly Hall's resume into MongoDB with additional fields
# Inserted David Henry's resume into MongoDB with additional fields
# Inserted Craig Harris's resume into MongoDB with additional fields
# Inserted Kristen Guerra's resume into MongoDB with additional fields
# Inserted Kenneth Fuentes's resume into MongoDB with additional fields
# Inserted Stephen Brooks's resume into MongoDB with additional fields
# Inserted Gabriel Hickman's resume into MongoDB with additional fields
# Inserted Daniel Anderson's resume into MongoDB with additional fields
# Inserted Roger Lawson's resume into MongoDB with additional fields
# Inserted Jamie Adams's resume into MongoDB with additional fields
# Inserted Eric Hansen's resume into MongoDB with additional fields
# Inserted Leslie Garcia's resume into MongoDB with additional fields
# Inserted Christina Roy's resume into MongoDB with additional fields
# Inserted Anthony Green's resume into MongoDB with additional fields
# Inserted Tara Little's resume into MongoDB with additional fields
# Inserted Miguel Flores's resume into MongoDB with additional fields
# Inserted Kelly Peterson's resume into MongoDB with additional fields
# Inserted Kelly Gilbert's resume into MongoDB with additional fields
# Inserted Ronald Jones's resume into MongoDB with additional fields
# Inserted Joshua Johnson's resume into MongoDB with additional fields
# Inserted Michael Middleton's resume into MongoDB with additional fields
# Inserted Grace Riley's resume into MongoDB with additional fields
# Inserted Lee Robertson's resume into MongoDB with additional fields
# Inserted Melissa Dixon's resume into MongoDB with additional fields
# Inserted Patrick Potts's resume into MongoDB with additional fields
# Inserted Daniel Mcdaniel's resume into MongoDB with additional fields
# Inserted Nicole Johnson's resume into MongoDB with additional fields
# Inserted Abigail Rose's resume into MongoDB with additional fields
# Inserted Ashlee Walton's resume into MongoDB with additional fields
# Inserted Lydia Davidson's resume into MongoDB with additional fields
# Inserted Monique Parks's resume into MongoDB with additional fields
# Inserted Katie Park's resume into MongoDB with additional fields
# Inserted Michelle Wiggins's resume into MongoDB with additional fields
# Inserted Angela Diaz's resume into MongoDB with additional fields
# Inserted Tracy Flores's resume into MongoDB with additional fields
# Inserted Christopher Santiago's resume into MongoDB with additional fields
# Inserted Jennifer Lindsey's resume into MongoDB with additional fields
# Inserted Nicole Mitchell's resume into MongoDB with additional fields
# Inserted Lindsey Andrews's resume into MongoDB with additional fields
# Inserted Ashley Mckinney's resume into MongoDB with additional fields
# Inserted Felicia Carlson's resume into MongoDB with additional fields
# Inserted Sean Hodge's resume into MongoDB with additional fields
# Inserted Jillian Ramirez's resume into MongoDB with additional fields
# Inserted Richard Gonzales's resume into MongoDB with additional fields
# Inserted Donald Nguyen's resume into MongoDB with additional fields
# Inserted Brandy Tucker's resume into MongoDB with additional fields
# Inserted Colton Stevens's resume into MongoDB with additional fields
# Inserted Victoria Lewis's resume into MongoDB with additional fields
# Inserted Katie Powell's resume into MongoDB with additional fields
# Inserted Mr. Thomas Glenn's resume into MongoDB with additional fields
# Inserted Mrs. Michelle Greer's resume into MongoDB with additional fields
# Inserted Cindy Smith's resume into MongoDB with additional fields
# Inserted Hannah Austin's resume into MongoDB with additional fields
# Inserted Megan Benitez's resume into MongoDB with additional fields
# Inserted Matthew Mclaughlin's resume into MongoDB with additional fields
# Inserted Tonya Brown's resume into MongoDB with additional fields
# Inserted Larry Weeks's resume into MongoDB with additional fields
# Inserted Thomas Hernandez's resume into MongoDB with additional fields
# Inserted Meredith Mcdonald's resume into MongoDB with additional fields
# Inserted George Williams's resume into MongoDB with additional fields
# Inserted Felicia Floyd's resume into MongoDB with additional fields
# Inserted Adam Hart's resume into MongoDB with additional fields
# Inserted Matthew Gutierrez's resume into MongoDB with additional fields
# Inserted Julie Rice's resume into MongoDB with additional fields
# Inserted Don Reed's resume into MongoDB with additional fields
# Inserted Justin Stevens's resume into MongoDB with additional fields
# Inserted William Hays's resume into MongoDB with additional fields
# Inserted Katherine Klein's resume into MongoDB with additional fields
# Inserted Ana Oneill's resume into MongoDB with additional fields
# Inserted Cassandra Beltran's resume into MongoDB with additional fields
# Inserted Nancy Mcpherson's resume into MongoDB with additional fields
# Inserted Gary Jones's resume into MongoDB with additional fields
# Inserted Charles Johnson's resume into MongoDB with additional fields
# Inserted Roger Rich's resume into MongoDB with additional fields
# Inserted Matthew Roberts's resume into MongoDB with additional fields
# Inserted Katherine Wallace's resume into MongoDB with additional fields
# Inserted Jessica Jones's resume into MongoDB with additional fields
# Inserted Javier Moore's resume into MongoDB with additional fields
# Inserted Kelly Clark's resume into MongoDB with additional fields
# Inserted Anna Mcneil's resume into MongoDB with additional fields
# Inserted James Johnson's resume into MongoDB with additional fields
# Inserted Tammy Baker's resume into MongoDB with additional fields
# Inserted Daniel Marshall's resume into MongoDB with additional fields
# Inserted Michael Andrews's resume into MongoDB with additional fields
# Inserted Megan White's resume into MongoDB with additional fields
# Inserted Robert Nixon's resume into MongoDB with additional fields
# Inserted Lisa Nichols's resume into MongoDB with additional fields
# Inserted Jeremy Tran's resume into MongoDB with additional fields
# Inserted Joseph Short's resume into MongoDB with additional fields
# Inserted Kevin Hickman's resume into MongoDB with additional fields
# Inserted Scott Hopkins's resume into MongoDB with additional fields
# Inserted Jeffrey Clark's resume into MongoDB with additional fields
# Inserted Matthew Foster's resume into MongoDB with additional fields
# Inserted Troy Bowman's resume into MongoDB with additional fields
# Inserted Michelle Vaughn's resume into MongoDB with additional fields
# Inserted Jessica Stevenson's resume into MongoDB with additional fields
# Inserted Troy Mills's resume into MongoDB with additional fields
# Inserted Tiffany Lin's resume into MongoDB with additional fields
# Inserted Stephanie Cooper's resume into MongoDB with additional fields
# Inserted Lee Brown's resume into MongoDB with additional fields
# Inserted Shane Hernandez's resume into MongoDB with additional fields
# Inserted Jeremy Schaefer's resume into MongoDB with additional fields
# Inserted Mrs. Chelsea Sanchez's resume into MongoDB with additional fields
# Inserted Jennifer Kelly's resume into MongoDB with additional fields
# Inserted Amanda Navarro's resume into MongoDB with additional fields
# Inserted Carl Hall's resume into MongoDB with additional fields
# Inserted James Long's resume into MongoDB with additional fields
# Inserted Travis Perez's resume into MongoDB with additional fields
# Inserted Christopher Richardson's resume into MongoDB with additional fields
# Inserted Tammy Gonzalez's resume into MongoDB with additional fields
# Inserted Charles Hamilton's resume into MongoDB with additional fields
# Inserted Joshua Watkins's resume into MongoDB with additional fields
# Inserted Terry Edwards's resume into MongoDB with additional fields
# Inserted Christopher Durham's resume into MongoDB with additional fields
# Inserted Sarah Adams's resume into MongoDB with additional fields
# Inserted Aaron Smith's resume into MongoDB with additional fields
# Inserted Aaron Coleman's resume into MongoDB with additional fields
# Inserted Troy Franklin's resume into MongoDB with additional fields
# Inserted Amanda Smith's resume into MongoDB with additional fields
# Inserted Sheryl Gutierrez's resume into MongoDB with additional fields
# Inserted John Bridges's resume into MongoDB with additional fields
# Inserted Brian Peters's resume into MongoDB with additional fields
# Inserted Michael Robertson's resume into MongoDB with additional fields
# Inserted Mrs. Regina Wilkinson MD's resume into MongoDB with additional fields
# Inserted Sandra Guerrero's resume into MongoDB with additional fields
# Inserted Troy Gray's resume into MongoDB with additional fields
# Inserted Cassandra Walker's resume into MongoDB with additional fields
# Inserted Denise Wallace PhD's resume into MongoDB with additional fields
# Inserted Kelly Alvarado's resume into MongoDB with additional fields
# Inserted Joshua Lane's resume into MongoDB with additional fields
# Inserted Michele Booth's resume into MongoDB with additional fields
# Inserted Linda Ho's resume into MongoDB with additional fields
# Inserted Haley Galloway's resume into MongoDB with additional fields
# Inserted Mr. Mark Rodriguez's resume into MongoDB with additional fields
# Inserted Thomas Key's resume into MongoDB with additional fields
# Inserted William Ewing's resume into MongoDB with additional fields
# Inserted Brian Martin's resume into MongoDB with additional fields
# Inserted Kevin Carter's resume into MongoDB with additional fields
# Inserted William Tucker's resume into MongoDB with additional fields
# Inserted Angela Taylor's resume into MongoDB with additional fields
# Inserted Evan Barber's resume into MongoDB with additional fields
# Inserted Michelle Phillips's resume into MongoDB with additional fields
# Inserted Elizabeth Mcguire's resume into MongoDB with additional fields
# Inserted Paul Bowen's resume into MongoDB with additional fields
# Inserted Johnny Padilla's resume into MongoDB with additional fields
# Inserted Terry Morris's resume into MongoDB with additional fields
# Inserted Maria Krause's resume into MongoDB with additional fields
# Inserted Christie Huynh's resume into MongoDB with additional fields
# Inserted Hunter Morales's resume into MongoDB with additional fields
# Inserted Pamela Casey's resume into MongoDB with additional fields
# Inserted David Erickson's resume into MongoDB with additional fields
# Inserted Ruth Wiley's resume into MongoDB with additional fields
# Inserted Frank Walters's resume into MongoDB with additional fields
# Inserted Kimberly Fischer's resume into MongoDB with additional fields
# Inserted Justin Griffin's resume into MongoDB with additional fields
# Inserted Valerie Ward's resume into MongoDB with additional fields
# Inserted Jacob Griffin's resume into MongoDB with additional fields
# Inserted Jason Hughes's resume into MongoDB with additional fields
# Inserted Andrew Rodriguez's resume into MongoDB with additional fields
# Inserted Eric Anderson's resume into MongoDB with additional fields
# Inserted Raymond Sanders's resume into MongoDB with additional fields
# Inserted Janet Pearson's resume into MongoDB with additional fields
# Inserted Jacob Howard's resume into MongoDB with additional fields
# Inserted Chad Campbell's resume into MongoDB with additional fields
# Inserted Daniel Torres's resume into MongoDB with additional fields
# Inserted Jane Smith's resume into MongoDB with additional fields
# Inserted Stephanie Schultz's resume into MongoDB with additional fields
# Inserted Suzanne Nelson's resume into MongoDB with additional fields
# Inserted Bradley Chaney's resume into MongoDB with additional fields
# Inserted Kristi Dillon's resume into MongoDB with additional fields
# Inserted Brandon Edwards's resume into MongoDB with additional fields
# Inserted Cheryl Garrison's resume into MongoDB with additional fields
# Inserted Jennifer Valenzuela's resume into MongoDB with additional fields
# Inserted Nathan Mitchell's resume into MongoDB with additional fields
# Inserted Amber Rodriguez's resume into MongoDB with additional fields
# Inserted Fernando Stone's resume into MongoDB with additional fields
# Inserted Trevor Dalton's resume into MongoDB with additional fields
# Inserted Monique Lawson's resume into MongoDB with additional fields
# Inserted Katherine Cochran's resume into MongoDB with additional fields
# Inserted Christopher Lindsey's resume into MongoDB with additional fields
# Inserted Sandra Hill's resume into MongoDB with additional fields
# Inserted Douglas Boyd's resume into MongoDB with additional fields
# Inserted Sean Meadows's resume into MongoDB with additional fields
# Inserted Cynthia Hill's resume into MongoDB with additional fields
# Inserted Ashley Cunningham's resume into MongoDB with additional fields
# Inserted Stephanie Richards's resume into MongoDB with additional fields
# Inserted Darius Meyer's resume into MongoDB with additional fields
# Inserted Hannah Stewart's resume into MongoDB with additional fields
# Inserted Angela Stevens's resume into MongoDB with additional fields
# Inserted Nicholas Perkins's resume into MongoDB with additional fields
# Inserted Scott Smith's resume into MongoDB with additional fields
# Inserted Nicole Morales's resume into MongoDB with additional fields
# Inserted Julie Salazar's resume into MongoDB with additional fields
# Inserted Brandon Meyers's resume into MongoDB with additional fields
# Inserted Lynn Calhoun's resume into MongoDB with additional fields
# Inserted Christopher Logan's resume into MongoDB with additional fields
# Inserted Richard Lopez's resume into MongoDB with additional fields
# Inserted Sherry Mcintosh's resume into MongoDB with additional fields
# Inserted Sara Blair's resume into MongoDB with additional fields
# Inserted Mary Thompson's resume into MongoDB with additional fields
# Inserted Kevin Underwood's resume into MongoDB with additional fields
# Inserted Kenneth Wells's resume into MongoDB with additional fields
# Inserted David Black's resume into MongoDB with additional fields
# Inserted April Zavala's resume into MongoDB with additional fields
# Inserted Randy Yang's resume into MongoDB with additional fields
# Inserted Gloria Garcia's resume into MongoDB with additional fields
# Inserted Miguel Wallace's resume into MongoDB with additional fields
# Inserted Tiffany Shaw's resume into MongoDB with additional fields
# Inserted Johnny Stokes's resume into MongoDB with additional fields
# Inserted Douglas Young's resume into MongoDB with additional fields
# Inserted Daniel Mason's resume into MongoDB with additional fields
# Inserted Christopher Torres's resume into MongoDB with additional fields
# Inserted Michael Chavez's resume into MongoDB with additional fields
# Inserted Douglas Moore's resume into MongoDB with additional fields
# Inserted Jason Marshall's resume into MongoDB with additional fields
# Inserted Catherine Allen's resume into MongoDB with additional fields
# Inserted Todd Gonzalez's resume into MongoDB with additional fields
# Inserted Wayne Hensley's resume into MongoDB with additional fields
# Inserted Edward Perkins's resume into MongoDB with additional fields
# Inserted Misty Smith's resume into MongoDB with additional fields
# Inserted Robin Thompson's resume into MongoDB with additional fields
# Inserted Matthew Rogers's resume into MongoDB with additional fields
# Inserted Amber Smith's resume into MongoDB with additional fields
# Inserted Lori Reynolds's resume into MongoDB with additional fields
# Inserted Tyrone Mccullough's resume into MongoDB with additional fields
# Inserted Carrie Robinson's resume into MongoDB with additional fields
# Inserted Rebecca Mcdaniel's resume into MongoDB with additional fields
# Inserted Jennifer Graham's resume into MongoDB with additional fields
# Inserted Jonathan Coleman's resume into MongoDB with additional fields
# Inserted Cesar Ramirez's resume into MongoDB with additional fields
# Inserted Michael Brown's resume into MongoDB with additional fields
# Inserted Nicole Rice's resume into MongoDB with additional fields
# Inserted Robert Newman's resume into MongoDB with additional fields
# Inserted Nicole Morgan's resume into MongoDB with additional fields
# Inserted Annette Spears's resume into MongoDB with additional fields
# Inserted Tammy Keith's resume into MongoDB with additional fields
# Inserted Krystal Montgomery's resume into MongoDB with additional fields
# Inserted Olivia Calderon's resume into MongoDB with additional fields
# Inserted Krista Myers's resume into MongoDB with additional fields
# Inserted Ryan Ellis's resume into MongoDB with additional fields
# Inserted Stephanie Buchanan's resume into MongoDB with additional fields
# Inserted Alexis Torres's resume into MongoDB with additional fields
# Inserted Ryan Barnes's resume into MongoDB with additional fields
# Inserted Randy Sims's resume into MongoDB with additional fields
# Inserted Annette Shepherd's resume into MongoDB with additional fields
# Inserted Jeremy Taylor's resume into MongoDB with additional fields
# Inserted Joshua Gonzalez's resume into MongoDB with additional fields
# Inserted Roger Davis's resume into MongoDB with additional fields
# Inserted Kimberly Patton's resume into MongoDB with additional fields
# Inserted Darrell Lucero's resume into MongoDB with additional fields
# Inserted Jeffery Sullivan's resume into MongoDB with additional fields
# Inserted Cody Richardson's resume into MongoDB with additional fields
# Inserted Hannah Massey's resume into MongoDB with additional fields
# Inserted Jennifer Hart's resume into MongoDB with additional fields
# Inserted Christina Porter's resume into MongoDB with additional fields
# Inserted Dakota Proctor's resume into MongoDB with additional fields
# Inserted Danielle Miller's resume into MongoDB with additional fields
# Inserted Christine Goodwin's resume into MongoDB with additional fields
# Inserted Gina Hogan's resume into MongoDB with additional fields
# Inserted James Edwards's resume into MongoDB with additional fields
# Inserted Laura Brown's resume into MongoDB with additional fields
# Inserted Jessica Foster's resume into MongoDB with additional fields
# Inserted Michael Miles's resume into MongoDB with additional fields
# Inserted Jenna Long's resume into MongoDB with additional fields
# Inserted Leonard Thomas's resume into MongoDB with additional fields
# Inserted Victoria Cooper's resume into MongoDB with additional fields
# Inserted Robert Rivera's resume into MongoDB with additional fields
# Inserted Kathleen Huerta's resume into MongoDB with additional fields
# Inserted Erica Hall's resume into MongoDB with additional fields
# Inserted Candice Andrade's resume into MongoDB with additional fields
# Inserted David Wagner's resume into MongoDB with additional fields
# Inserted Kenneth Wheeler's resume into MongoDB with additional fields
# Inserted Zachary Zimmerman's resume into MongoDB with additional fields
# Inserted Christina Owens's resume into MongoDB with additional fields
# Inserted Toni Bryan's resume into MongoDB with additional fields
# Inserted Anthony Ford's resume into MongoDB with additional fields
# Inserted Donald Jones's resume into MongoDB with additional fields
# Inserted Roger Camacho's resume into MongoDB with additional fields
# Inserted Barbara Curtis's resume into MongoDB with additional fields
# Inserted Stacey Bryant's resume into MongoDB with additional fields
# Inserted Teresa Ray's resume into MongoDB with additional fields
# Inserted Michael Cook's resume into MongoDB with additional fields
# Inserted Brianna Hawkins's resume into MongoDB with additional fields
# Inserted Elizabeth Howard's resume into MongoDB with additional fields
# Inserted Alejandro Moore's resume into MongoDB with additional fields
# Inserted Shannon Nguyen's resume into MongoDB with additional fields
# Inserted Calvin Ross's resume into MongoDB with additional fields
# Inserted Brett Hughes's resume into MongoDB with additional fields
# Inserted Jonathan Edwards's resume into MongoDB with additional fields
# Inserted Martin Smith's resume into MongoDB with additional fields
# Inserted Darrell Walker's resume into MongoDB with additional fields
# Inserted Robert Williams's resume into MongoDB with additional fields
# Inserted Christopher Nichols's resume into MongoDB with additional fields
# Inserted Alexander Fisher's resume into MongoDB with additional fields
# Inserted Leah Keller's resume into MongoDB with additional fields
# Inserted Sarah Meza's resume into MongoDB with additional fields
# Inserted Marilyn Stokes's resume into MongoDB with additional fields
# Inserted Thomas Gonzalez's resume into MongoDB with additional fields
# Inserted Jennifer Heath's resume into MongoDB with additional fields
# Inserted Andrew Little's resume into MongoDB with additional fields
# Inserted Teresa Jenkins DDS's resume into MongoDB with additional fields
# Inserted Brenda Vargas's resume into MongoDB with additional fields
# Inserted Brooke Williams's resume into MongoDB with additional fields
# Inserted Joseph Cole's resume into MongoDB with additional fields
# Inserted Victoria Salazar's resume into MongoDB with additional fields
# Inserted Danielle Whitaker's resume into MongoDB with additional fields
# Inserted Anne Brewer's resume into MongoDB with additional fields
# Inserted Dr. George Bautista's resume into MongoDB with additional fields
# Inserted Robert Blake's resume into MongoDB with additional fields
# Inserted Sarah Brennan's resume into MongoDB with additional fields
# Inserted Jason Farmer's resume into MongoDB with additional fields
# Inserted Tina Grimes's resume into MongoDB with additional fields
# Inserted Jessica Watson's resume into MongoDB with additional fields
# Inserted James Allen's resume into MongoDB with additional fields
# Inserted Russell Dixon's resume into MongoDB with additional fields
# Inserted Alexandra Olsen's resume into MongoDB with additional fields
# Inserted David Nash's resume into MongoDB with additional fields
# Inserted Anthony Carroll's resume into MongoDB with additional fields
# Inserted Sonya Cisneros's resume into MongoDB with additional fields
# Inserted Penny Martinez's resume into MongoDB with additional fields
# Inserted Ronald Huff's resume into MongoDB with additional fields
# Inserted Elizabeth Gibbs's resume into MongoDB with additional fields
# Inserted Mark Booth's resume into MongoDB with additional fields
# Inserted Javier Ramos's resume into MongoDB with additional fields
# Inserted Michael Spencer's resume into MongoDB with additional fields
# Inserted James Lindsey's resume into MongoDB with additional fields
# Inserted Joseph Bolton's resume into MongoDB with additional fields
# Inserted Jill Clements MD's resume into MongoDB with additional fields
# Inserted Sara Little's resume into MongoDB with additional fields
# Inserted Samantha Ortiz's resume into MongoDB with additional fields
# Inserted Scott Sanchez's resume into MongoDB with additional fields
# Inserted Lori Ho's resume into MongoDB with additional fields
# Inserted John Brown's resume into MongoDB with additional fields
# Inserted Alan Hardy's resume into MongoDB with additional fields
# Inserted Nicole Howell's resume into MongoDB with additional fields
# Inserted Courtney Hernandez's resume into MongoDB with additional fields
# Inserted Lauren Schmidt's resume into MongoDB with additional fields
# Inserted Jennifer Walsh's resume into MongoDB with additional fields
# Inserted Melissa Mills's resume into MongoDB with additional fields
# Inserted Kristin Davis's resume into MongoDB with additional fields
# Inserted Crystal Gilbert's resume into MongoDB with additional fields
# Inserted John Hendricks's resume into MongoDB with additional fields
# Inserted James Valentine's resume into MongoDB with additional fields
# Inserted Haley Kelly's resume into MongoDB with additional fields
# Inserted William Moore's resume into MongoDB with additional fields
# Inserted Antonio Owens's resume into MongoDB with additional fields
# Inserted Robin Hicks's resume into MongoDB with additional fields
# Inserted Benjamin Johns's resume into MongoDB with additional fields
# Inserted Matthew Ferguson's resume into MongoDB with additional fields
# Inserted Robert Middleton's resume into MongoDB with additional fields
# Inserted Jennifer Scott's resume into MongoDB with additional fields
# Inserted Kayla Jordan's resume into MongoDB with additional fields
# Inserted Ashley Johnson's resume into MongoDB with additional fields
# Inserted Shirley Stokes's resume into MongoDB with additional fields
# Inserted Robyn Bowman's resume into MongoDB with additional fields
# Inserted Jimmy Hill's resume into MongoDB with additional fields
# Inserted Angela Lee's resume into MongoDB with additional fields
# Inserted Jeffrey Beasley's resume into MongoDB with additional fields
# Inserted Glen Ramirez's resume into MongoDB with additional fields
# Inserted Michelle Ryan's resume into MongoDB with additional fields
# Inserted Alexandria Mcintyre's resume into MongoDB with additional fields
# Inserted Ian Cruz's resume into MongoDB with additional fields
# Inserted Robert Hernandez's resume into MongoDB with additional fields
# Inserted Michael Moore's resume into MongoDB with additional fields
# Inserted Scott Whitney's resume into MongoDB with additional fields
# Inserted Kayla Davis's resume into MongoDB with additional fields
# Inserted Benjamin Vazquez's resume into MongoDB with additional fields
# Inserted Brian Anderson's resume into MongoDB with additional fields
# Inserted Kristin Curry's resume into MongoDB with additional fields
# Inserted Joshua Moore's resume into MongoDB with additional fields
# Inserted Deanna Grimes's resume into MongoDB with additional fields
# Inserted Ashley Zimmerman's resume into MongoDB with additional fields
# Inserted Nicole Wright's resume into MongoDB with additional fields
# Inserted David Collins's resume into MongoDB with additional fields
# Inserted David Fleming's resume into MongoDB with additional fields
# Inserted James Wilson DDS's resume into MongoDB with additional fields
# Inserted Nicholas Reed's resume into MongoDB with additional fields
# Inserted Jack Robertson's resume into MongoDB with additional fields
# Inserted Joshua Jones's resume into MongoDB with additional fields
# Inserted Danielle Bennett's resume into MongoDB with additional fields
# Inserted Robert Silva's resume into MongoDB with additional fields
# Inserted William Alexander Jr.'s resume into MongoDB with additional fields
# Inserted Heather Oconnor's resume into MongoDB with additional fields
# Inserted Brittany Miller's resume into MongoDB with additional fields
# Inserted Jennifer Marshall's resume into MongoDB with additional fields
# Inserted Rebecca Larsen's resume into MongoDB with additional fields
# Inserted Sarah Thomas's resume into MongoDB with additional fields
# Inserted Colleen Salazar's resume into MongoDB with additional fields
# Inserted Sarah Hernandez's resume into MongoDB with additional fields
# Inserted Karen Carter's resume into MongoDB with additional fields
# Inserted Adam Savage's resume into MongoDB with additional fields
# Inserted John Henderson's resume into MongoDB with additional fields
# Inserted Jacqueline Kaufman's resume into MongoDB with additional fields
# Inserted Ann Anderson's resume into MongoDB with additional fields
# Inserted Randy Hood's resume into MongoDB with additional fields
# Inserted Debbie King's resume into MongoDB with additional fields
# Inserted Michael Black's resume into MongoDB with additional fields
# Inserted Jesus Shelton's resume into MongoDB with additional fields
# Inserted Maria Wong's resume into MongoDB with additional fields
# Inserted Kenneth Thompson's resume into MongoDB with additional fields
# Inserted Bobby Davidson's resume into MongoDB with additional fields
# Inserted Mark Barrett's resume into MongoDB with additional fields
# Inserted Elizabeth Sanchez's resume into MongoDB with additional fields
# Inserted Jessica Brown's resume into MongoDB with additional fields
# Inserted Margaret Rodriguez's resume into MongoDB with additional fields
# Inserted Travis Rodriguez's resume into MongoDB with additional fields
# Inserted Victoria Cantrell's resume into MongoDB with additional fields
# Inserted Charles Bruce's resume into MongoDB with additional fields
# Inserted Hailey Rose's resume into MongoDB with additional fields
# Inserted Krystal Frazier's resume into MongoDB with additional fields
# Inserted Sarah Schmidt's resume into MongoDB with additional fields
# Inserted Megan Sampson's resume into MongoDB with additional fields
# Inserted Miranda Spencer's resume into MongoDB with additional fields
# Inserted Brian Bennett DDS's resume into MongoDB with additional fields
# Inserted Meghan Burke's resume into MongoDB with additional fields
# Inserted Julia Collins's resume into MongoDB with additional fields
# Inserted Julie Green's resume into MongoDB with additional fields
# Inserted Charles Washington's resume into MongoDB with additional fields
# Inserted Keith Poole's resume into MongoDB with additional fields
# Inserted Kathleen Cain's resume into MongoDB with additional fields
# Inserted Donald Saunders's resume into MongoDB with additional fields
# Inserted Linda Griffin's resume into MongoDB with additional fields
# Inserted Cody Little's resume into MongoDB with additional fields
# Inserted Sean Rivera's resume into MongoDB with additional fields
# Inserted Mary Smith's resume into MongoDB with additional fields
# Inserted Allison Hudson's resume into MongoDB with additional fields
# Inserted Russell Reese's resume into MongoDB with additional fields
# Inserted Eugene Gray's resume into MongoDB with additional fields
# Inserted Mark Rosales's resume into MongoDB with additional fields
# Inserted Ryan Lewis's resume into MongoDB with additional fields
# Inserted Ashley Bradley's resume into MongoDB with additional fields
# Inserted Veronica Alvarado's resume into MongoDB with additional fields
# Inserted John Vasquez's resume into MongoDB with additional fields
# Inserted Claire Alexander's resume into MongoDB with additional fields
# Inserted Joanna Chan's resume into MongoDB with additional fields
# Inserted Amanda Martinez's resume into MongoDB with additional fields
# Inserted Robert Vincent's resume into MongoDB with additional fields
# Inserted Gloria Flynn's resume into MongoDB with additional fields
# Inserted James Bryant's resume into MongoDB with additional fields
# Inserted James Summers's resume into MongoDB with additional fields
# Inserted Rebecca Anderson's resume into MongoDB with additional fields
# Inserted Richard Miller's resume into MongoDB with additional fields
# Inserted Ann Fischer's resume into MongoDB with additional fields
# Inserted Jose Robinson's resume into MongoDB with additional fields
# Inserted Adam Smith's resume into MongoDB with additional fields
# Inserted Misty Pena PhD's resume into MongoDB with additional fields
# Inserted Scott Merritt's resume into MongoDB with additional fields
# Inserted John Pollard's resume into MongoDB with additional fields
# Inserted Brent Lee's resume into MongoDB with additional fields
# Inserted Maria Reynolds's resume into MongoDB with additional fields
# Inserted Juan Hammond's resume into MongoDB with additional fields
# Inserted Sara Hoffman's resume into MongoDB with additional fields
# Inserted Natalie Gilbert's resume into MongoDB with additional fields
# Inserted Kelly Erickson's resume into MongoDB with additional fields
# Inserted Cindy Castaneda's resume into MongoDB with additional fields
# Inserted John Smith's resume into MongoDB with additional fields
# Inserted Julie Nichols's resume into MongoDB with additional fields
# Inserted Emily Dodson's resume into MongoDB with additional fields
# Inserted Jennifer Rogers's resume into MongoDB with additional fields
# Inserted Julia Kennedy's resume into MongoDB with additional fields
# Inserted Tamara Le's resume into MongoDB with additional fields
# Inserted Joshua Carroll's resume into MongoDB with additional fields
# Inserted Ryan Stevens's resume into MongoDB with additional fields
# Inserted Stephanie Price's resume into MongoDB with additional fields
# Inserted Dwayne Cole's resume into MongoDB with additional fields
# Inserted Jennifer Walton's resume into MongoDB with additional fields
# Inserted Richard Stevenson's resume into MongoDB with additional fields
# Inserted Amy Edwards's resume into MongoDB with additional fields
# Inserted Michael Watson's resume into MongoDB with additional fields
# Inserted Joseph Smith's resume into MongoDB with additional fields
# Inserted Lauren Barnett's resume into MongoDB with additional fields
# Inserted Christine Garcia's resume into MongoDB with additional fields
# Inserted Joanna Thornton's resume into MongoDB with additional fields
# Inserted Mrs. Pamela Beard's resume into MongoDB with additional fields
# Inserted Angel Green's resume into MongoDB with additional fields
# Inserted Marcus Hawkins's resume into MongoDB with additional fields
# Inserted Stephanie Thomas's resume into MongoDB with additional fields
# Inserted Christopher Hatfield PhD's resume into MongoDB with additional fields
# Inserted Susan Castillo's resume into MongoDB with additional fields
# Inserted Catherine Nielsen's resume into MongoDB with additional fields
# Inserted Desiree Pace's resume into MongoDB with additional fields
# Inserted Jill Morgan's resume into MongoDB with additional fields
# Inserted Krista Harmon's resume into MongoDB with additional fields
# Inserted Darren Austin's resume into MongoDB with additional fields
# Inserted Jennifer Miller's resume into MongoDB with additional fields
# Inserted Curtis Martin's resume into MongoDB with additional fields
# Inserted Mark Rogers's resume into MongoDB with additional fields
# Inserted Brandon Hall's resume into MongoDB with additional fields
# Inserted Corey Baker's resume into MongoDB with additional fields
# Inserted Kelly Carr PhD's resume into MongoDB with additional fields
# Inserted Miguel Miller's resume into MongoDB with additional fields
# Inserted Tina Banks's resume into MongoDB with additional fields
# Inserted Tammy Henry's resume into MongoDB with additional fields
# Inserted Jacob Cooper's resume into MongoDB with additional fields
# Inserted Brett Reyes's resume into MongoDB with additional fields
# Inserted Tanner Wagner's resume into MongoDB with additional fields
# Inserted David Long's resume into MongoDB with additional fields
# Inserted Leslie Johnson's resume into MongoDB with additional fields
# Inserted Jose Mcconnell's resume into MongoDB with additional fields
# Inserted Kimberly Clark's resume into MongoDB with additional fields
# Inserted Patricia Rodriguez's resume into MongoDB with additional fields
# Inserted Kathleen Krause's resume into MongoDB with additional fields
# Inserted Jennifer Ramirez's resume into MongoDB with additional fields
# Inserted Elizabeth Roy's resume into MongoDB with additional fields
# Inserted Lori Hanson's resume into MongoDB with additional fields
# Inserted Scott Brown's resume into MongoDB with additional fields
# Inserted Autumn Jones's resume into MongoDB with additional fields
# Inserted Emily Torres's resume into MongoDB with additional fields
# Inserted Jeffrey Little's resume into MongoDB with additional fields
# Inserted Troy Scott's resume into MongoDB with additional fields
# Inserted Christopher Ramirez's resume into MongoDB with additional fields
# Inserted Michael Thomas's resume into MongoDB with additional fields
# Inserted Robert Mckay's resume into MongoDB with additional fields
# Inserted Katherine Contreras's resume into MongoDB with additional fields
# Inserted Susan Dixon's resume into MongoDB with additional fields
# Inserted Dennis Stein's resume into MongoDB with additional fields
# Inserted Ryan Leonard's resume into MongoDB with additional fields
# Inserted Sheila Norris's resume into MongoDB with additional fields
# Inserted Courtney Hart's resume into MongoDB with additional fields
# Inserted Richard Foster's resume into MongoDB with additional fields
# Inserted Christopher Wade's resume into MongoDB with additional fields
# Inserted Kevin Kline's resume into MongoDB with additional fields
# Inserted Frances Hart's resume into MongoDB with additional fields
# Inserted Harry Flynn's resume into MongoDB with additional fields
# Inserted Ms. Brittany Barton's resume into MongoDB with additional fields
# Inserted Rebecca Lopez's resume into MongoDB with additional fields
# Inserted Anna Reid's resume into MongoDB with additional fields
# Inserted Paul Sanchez's resume into MongoDB with additional fields
# Inserted Terry Gutierrez's resume into MongoDB with additional fields
# Inserted Linda Short's resume into MongoDB with additional fields
# Inserted Karina Jones's resume into MongoDB with additional fields
# Inserted Stephanie Jordan's resume into MongoDB with additional fields
# Inserted Michael Schneider's resume into MongoDB with additional fields
# Inserted Nicholas Munoz's resume into MongoDB with additional fields
# Inserted Timothy Stanley's resume into MongoDB with additional fields
# Inserted Luke Cabrera's resume into MongoDB with additional fields
# Inserted Norman Figueroa's resume into MongoDB with additional fields
# Inserted Carolyn Moore's resume into MongoDB with additional fields
# Inserted Amy Castro's resume into MongoDB with additional fields
# Inserted Gregory Roman's resume into MongoDB with additional fields
# Inserted Paul Martin's resume into MongoDB with additional fields
# Inserted William Gallagher's resume into MongoDB with additional fields
# Inserted Joshua Wright's resume into MongoDB with additional fields
# Inserted James Estes's resume into MongoDB with additional fields
# Inserted Brian Colon's resume into MongoDB with additional fields
# Inserted Malik Morrison's resume into MongoDB with additional fields
# Inserted Nathan Walker's resume into MongoDB with additional fields
# Inserted Kayla Scott's resume into MongoDB with additional fields
# Inserted Alexis Roberts's resume into MongoDB with additional fields
# Inserted Justin Salas's resume into MongoDB with additional fields
# Inserted Emily Sanders's resume into MongoDB with additional fields
# Inserted Samantha Cruz's resume into MongoDB with additional fields
# Inserted David Kim's resume into MongoDB with additional fields
# Inserted Reginald Hale's resume into MongoDB with additional fields
# Inserted Taylor Tanner's resume into MongoDB with additional fields
# Inserted Daniel Hawkins's resume into MongoDB with additional fields
# Inserted Jessica Smith's resume into MongoDB with additional fields
# Inserted Emily Miller's resume into MongoDB with additional fields
# Inserted Maria Clay's resume into MongoDB with additional fields
# Inserted Paul Williams's resume into MongoDB with additional fields
# Inserted Joseph Brown's resume into MongoDB with additional fields
# Inserted Adam Todd's resume into MongoDB with additional fields
# Inserted Barbara White's resume into MongoDB with additional fields
# Inserted James Mason's resume into MongoDB with additional fields
# Inserted James Lee's resume into MongoDB with additional fields
# Inserted Julie Walters's resume into MongoDB with additional fields
# Inserted Danielle Humphrey's resume into MongoDB with additional fields
# Inserted Ronald Foster's resume into MongoDB with additional fields
# Inserted Tyler Perkins's resume into MongoDB with additional fields
# Inserted Erica Gibbs's resume into MongoDB with additional fields
# Inserted Nicole Bradshaw's resume into MongoDB with additional fields
# Inserted Beth Beasley's resume into MongoDB with additional fields
# Inserted Adam Moore's resume into MongoDB with additional fields
# Inserted Brian Johnson's resume into MongoDB with additional fields
# Inserted Nicholas Armstrong's resume into MongoDB with additional fields
# Inserted Keith Spencer's resume into MongoDB with additional fields
# Inserted Laura Henderson's resume into MongoDB with additional fields
# Inserted Elizabeth Yates's resume into MongoDB with additional fields
# Inserted Evan Hancock's resume into MongoDB with additional fields
# Inserted William Byrd's resume into MongoDB with additional fields
# Inserted Ariel Lee's resume into MongoDB with additional fields
# Inserted Becky Osborne's resume into MongoDB with additional fields
# Inserted Michael Brown's resume into MongoDB with additional fields
# Inserted Timothy Brooks's resume into MongoDB with additional fields
# Inserted Heather Davis's resume into MongoDB with additional fields
# Inserted Isaac Miranda's resume into MongoDB with additional fields
# Inserted John Joyce's resume into MongoDB with additional fields
# Inserted Jordan Woods's resume into MongoDB with additional fields
# Inserted Kari Newton's resume into MongoDB with additional fields
# Inserted Sabrina Walker's resume into MongoDB with additional fields
# Inserted Jack Jackson's resume into MongoDB with additional fields
# Inserted Michael White's resume into MongoDB with additional fields
# Inserted Christopher Carpenter's resume into MongoDB with additional fields
# Inserted Margaret Rivas's resume into MongoDB with additional fields
# Inserted Melanie Roberts's resume into MongoDB with additional fields
# Inserted Austin Garner's resume into MongoDB with additional fields
# Inserted John Wilson's resume into MongoDB with additional fields
# Inserted Jeremy Green's resume into MongoDB with additional fields
# Inserted Anthony Daniel's resume into MongoDB with additional fields
# Inserted Kathy Lewis's resume into MongoDB with additional fields
# Inserted Keith Cobb's resume into MongoDB with additional fields
# Inserted Cody Lewis's resume into MongoDB with additional fields
# Inserted Shannon Barajas's resume into MongoDB with additional fields
# Inserted Diana Powers's resume into MongoDB with additional fields
# Inserted Amber Murphy's resume into MongoDB with additional fields
# Inserted Kelsey Gordon's resume into MongoDB with additional fields
# Inserted Jeffrey Buchanan's resume into MongoDB with additional fields
# Inserted Andrew Robinson's resume into MongoDB with additional fields
# Inserted Sherry Bentley's resume into MongoDB with additional fields
# Inserted Brent Simpson's resume into MongoDB with additional fields
# Inserted Sean Rice's resume into MongoDB with additional fields
# Inserted Phillip Delacruz's resume into MongoDB with additional fields
# Inserted Patricia Esparza's resume into MongoDB with additional fields
# Inserted Jessica Hopkins's resume into MongoDB with additional fields
# Inserted Michael Lang's resume into MongoDB with additional fields
# Inserted Wesley Snyder's resume into MongoDB with additional fields
# Inserted Zachary Jefferson's resume into MongoDB with additional fields
# Inserted Brandon Conley's resume into MongoDB with additional fields
# Inserted Brittany Hunter's resume into MongoDB with additional fields
# Inserted Stacy Todd's resume into MongoDB with additional fields
# Inserted Sheri Simmons's resume into MongoDB with additional fields
# Inserted Jennifer Anderson's resume into MongoDB with additional fields
# Inserted Andrew Singh's resume into MongoDB with additional fields
# Inserted Mrs. Morgan Brown's resume into MongoDB with additional fields
# Inserted Brenda Cannon's resume into MongoDB with additional fields
# Inserted Anthony Shields's resume into MongoDB with additional fields
# Inserted Dennis Smith's resume into MongoDB with additional fields
# Inserted Erica Carney's resume into MongoDB with additional fields
# Inserted William Peterson's resume into MongoDB with additional fields
# Inserted Jenna Ferguson's resume into MongoDB with additional fields
# Inserted Patrick Baker's resume into MongoDB with additional fields
# Inserted Laura Pierce's resume into MongoDB with additional fields
# Inserted Andrew Fuller's resume into MongoDB with additional fields
# Inserted Kayla Williams's resume into MongoDB with additional fields
# Inserted Zachary Wells's resume into MongoDB with additional fields
# Inserted Michael Jones's resume into MongoDB with additional fields
# Inserted John Crosby's resume into MongoDB with additional fields
# Inserted Jesus Horton's resume into MongoDB with additional fields
# Inserted Emily Watson's resume into MongoDB with additional fields
# Inserted Robin Fuentes's resume into MongoDB with additional fields
# Inserted Lauren Daugherty's resume into MongoDB with additional fields
# Inserted Veronica Reed PhD's resume into MongoDB with additional fields
# Inserted Angel White's resume into MongoDB with additional fields
# Inserted Isabella Frank's resume into MongoDB with additional fields
# Inserted Molly Marks's resume into MongoDB with additional fields
# Inserted Frank Ortiz MD's resume into MongoDB with additional fields
# Inserted Felicia Ryan's resume into MongoDB with additional fields
# Inserted Michele Thomas's resume into MongoDB with additional fields
# Inserted Melissa Flores's resume into MongoDB with additional fields
# Inserted Alicia Crawford's resume into MongoDB with additional fields
# Inserted Daryl Williams's resume into MongoDB with additional fields
# Inserted Nancy Hall's resume into MongoDB with additional fields
# Inserted Katrina Harris's resume into MongoDB with additional fields
# Inserted Natalie Hicks's resume into MongoDB with additional fields
# Inserted Courtney James's resume into MongoDB with additional fields
# Inserted Jacob Black's resume into MongoDB with additional fields
# Inserted Patty Mckinney's resume into MongoDB with additional fields
# Inserted Deborah Hernandez's resume into MongoDB with additional fields
# Inserted Mrs. Heather Nunez DDS's resume into MongoDB with additional fields
# Inserted Theresa Whitaker's resume into MongoDB with additional fields
# Inserted Vanessa Crawford's resume into MongoDB with additional fields
# Inserted Anita Coleman's resume into MongoDB with additional fields
# Inserted Jennifer Alvarez's resume into MongoDB with additional fields
# ...
# Inserted Melissa Francis's resume into MongoDB with additional fields
# Inserted Linda Hughes's resume into MongoDB with additional fields
# Inserted Linda Welch's resume into MongoDB with additional fields
# Inserted Lisa Richards's resume into MongoDB with additional fields
# Inserted Sonya Henry's resume into MongoDB with additional fields
# Inserted Drew Green's resume into MongoDB with additional fields
# Inserted Amy Carter's resume into MongoDB with additional fields
# Inserted Daniel Matthews's resume into MongoDB with additional fields
# Inserted Jeremy Meyer's resume into MongoDB with additional fields
# Inserted Yvonne Gonzalez's resume into MongoDB with additional fields
# Inserted Christopher Rose's resume into MongoDB with additional fields
# Inserted Joshua Duarte's resume into MongoDB with additional fields
# Inserted Howard Williams's resume into MongoDB with additional fields
# Inserted Jessica King's resume into MongoDB with additional fields
# Inserted Christopher Shepard's resume into MongoDB with additional fields
# Inserted Matthew Thompson's resume into MongoDB with additional fields
# Inserted Brittany Figueroa's resume into MongoDB with additional fields
# Inserted Anthony Gomez's resume into MongoDB with additional fields
# Inserted Anna Petersen's resume into MongoDB with additional fields
# Inserted Kimberly Anderson's resume into MongoDB with additional fields
# Inserted Amanda Fuller's resume into MongoDB with additional fields
# Inserted Steven Lewis's resume into MongoDB with additional fields
# Inserted Susan Gilbert's resume into MongoDB with additional fields
# Inserted Wendy Valencia's resume into MongoDB with additional fields
# Inserted Carrie Garcia's resume into MongoDB with additional fields
# Inserted Eric Long's resume into MongoDB with additional fields
# Inserted Stephen Stevens's resume into MongoDB with additional fields
# Inserted Jeffrey Randolph's resume into MongoDB with additional fields
# Inserted Jason Bush's resume into MongoDB with additional fields
# Inserted Rachel Little's resume into MongoDB with additional fields
# Inserted Michael Hamilton's resume into MongoDB with additional fields
# Inserted Frederick Mcmillan's resume into MongoDB with additional fields
# Inserted Amy Neal's resume into MongoDB with additional fields
# Inserted Austin Jones's resume into MongoDB with additional fields
# Inserted Kimberly Taylor's resume into MongoDB with additional fields
# Inserted Kristin Gay's resume into MongoDB with additional fields
# Inserted Kathleen Powers's resume into MongoDB with additional fields
# Inserted Kelly Torres's resume into MongoDB with additional fields
# Inserted Jacob Simpson's resume into MongoDB with additional fields
# Inserted Laura Mays's resume into MongoDB with additional fields
# Inserted Larry Douglas's resume into MongoDB with additional fields
# Inserted Laura Bell's resume into MongoDB with additional fields
# Inserted Shawn Abbott's resume into MongoDB with additional fields
# Inserted Jennifer Mitchell's resume into MongoDB with additional fields
# Inserted James Vargas's resume into MongoDB with additional fields
# Inserted Ricky Wolfe's resume into MongoDB with additional fields
# Inserted John Patel's resume into MongoDB with additional fields
# Inserted Crystal Phillips's resume into MongoDB with additional fields
# Inserted Steven Mckinney's resume into MongoDB with additional fields
# Inserted Richard Taylor's resume into MongoDB with additional fields
# Inserted Angela Daniels's resume into MongoDB with additional fields
# Inserted Ashley Hester's resume into MongoDB with additional fields
# Inserted Nicholas Wilcox's resume into MongoDB with additional fields
# Inserted Robert Butler's resume into MongoDB with additional fields
# Inserted Amanda Jefferson's resume into MongoDB with additional fields
# Inserted Heather Ramos's resume into MongoDB with additional fields
# Inserted Kristin Duran's resume into MongoDB with additional fields
# Inserted Matthew Ray's resume into MongoDB with additional fields
# Inserted Stephen Clark's resume into MongoDB with additional fields
# Inserted Erika Shaw's resume into MongoDB with additional fields
# Inserted Aaron Clay's resume into MongoDB with additional fields
# Inserted Carol Hopkins's resume into MongoDB with additional fields
# Inserted Kelly Lewis's resume into MongoDB with additional fields
# Inserted James Oneill's resume into MongoDB with additional fields
# Inserted Alison Powell's resume into MongoDB with additional fields
# Inserted Janet Ramirez's resume into MongoDB with additional fields
# Inserted Brian Wood's resume into MongoDB with additional fields
# Inserted Edgar Gibson's resume into MongoDB with additional fields
# Inserted Carolyn Becker's resume into MongoDB with additional fields
# Inserted Nathan Nielsen's resume into MongoDB with additional fields
# Inserted Mrs. Margaret Walker's resume into MongoDB with additional fields
# Inserted Christine Johnston's resume into MongoDB with additional fields
# Inserted Cynthia Ramos's resume into MongoDB with additional fields
# Inserted Jason Walsh's resume into MongoDB with additional fields
# Inserted Shannon Powell's resume into MongoDB with additional fields
# Inserted James Green's resume into MongoDB with additional fields
# Inserted Nathaniel Walters's resume into MongoDB with additional fields
# Inserted Amanda Merritt's resume into MongoDB with additional fields
# Inserted Laura Mccarty's resume into MongoDB with additional fields
# Inserted Catherine Clay's resume into MongoDB with additional fields
# Inserted Pamela Davidson's resume into MongoDB with additional fields
# Inserted Angela Weaver's resume into MongoDB with additional fields
# Inserted Christina Powers's resume into MongoDB with additional fields
# Inserted Jennifer Doyle DVM's resume into MongoDB with additional fields
# Inserted Maria Boyle's resume into MongoDB with additional fields
# Inserted Amber Jordan's resume into MongoDB with additional fields
# Inserted Travis Turner's resume into MongoDB with additional fields
# Inserted Blake Griffin's resume into MongoDB with additional fields
# Inserted Brittany Cole's resume into MongoDB with additional fields
# Inserted Kenneth Nicholson's resume into MongoDB with additional fields
# Inserted Betty Collins's resume into MongoDB with additional fields
# Inserted Matthew Moon's resume into MongoDB with additional fields
# Inserted Kimberly Boyd's resume into MongoDB with additional fields
# Inserted John Stephens's resume into MongoDB with additional fields
# Inserted Krista Wood's resume into MongoDB with additional fields
# Inserted Philip Vargas's resume into MongoDB with additional fields
# Inserted Cynthia Phillips's resume into MongoDB with additional fields
# Inserted Wanda Jones's resume into MongoDB with additional fields
# Inserted Jeffrey Berry's resume into MongoDB with additional fields
# Inserted Adam Wolf's resume into MongoDB with additional fields
# Inserted Nicholas Jones's resume into MongoDB with additional fields
# Inserted Ashley Price's resume into MongoDB with additional fields
# Inserted Dawn Castro's resume into MongoDB with additional fields
# Inserted Heather Patterson DDS's resume into MongoDB with additional fields
# Inserted Nathaniel Elliott's resume into MongoDB with additional fields
# Inserted Carrie Ward DDS's resume into MongoDB with additional fields
# Inserted Jennifer Curtis's resume into MongoDB with additional fields
# Inserted Samuel Anderson's resume into MongoDB with additional fields
# Inserted Dr. Tracy Collins MD's resume into MongoDB with additional fields
# Inserted Michelle Perez's resume into MongoDB with additional fields
# Inserted Erica Green's resume into MongoDB with additional fields
# Inserted Matthew Garcia's resume into MongoDB with additional fields
# Inserted Monica Cook's resume into MongoDB with additional fields
# Inserted William Hernandez's resume into MongoDB with additional fields
# Inserted Alexander Curtis's resume into MongoDB with additional fields
# Inserted Janet Weeks's resume into MongoDB with additional fields
# Inserted Joseph Moore's resume into MongoDB with additional fields
# Inserted Lisa Sandoval's resume into MongoDB with additional fields
# Inserted Jesse Taylor's resume into MongoDB with additional fields
# Inserted Susan Rush's resume into MongoDB with additional fields
# Inserted Mike Garcia MD's resume into MongoDB with additional fields
# Inserted Joy Cisneros's resume into MongoDB with additional fields
# Inserted Elizabeth Krause's resume into MongoDB with additional fields
# Inserted Rebecca Tucker's resume into MongoDB with additional fields
# Inserted Alfred Schroeder's resume into MongoDB with additional fields
# Inserted Matthew Harris's resume into MongoDB with additional fields
# Inserted Jeffery Higgins's resume into MongoDB with additional fields
# Inserted Kelly Scott's resume into MongoDB with additional fields
# Inserted Ronald Gibson's resume into MongoDB with additional fields
# Inserted Isaac Harrell's resume into MongoDB with additional fields
# Inserted David Chen's resume into MongoDB with additional fields
# Inserted Kayla Clark's resume into MongoDB with additional fields
# Inserted Kimberly Mclean's resume into MongoDB with additional fields
# Inserted Regina Hernandez's resume into MongoDB with additional fields
# Inserted David Wallace's resume into MongoDB with additional fields
# Inserted Dustin Rodriguez's resume into MongoDB with additional fields
# Inserted Jesse Monroe's resume into MongoDB with additional fields
# Inserted Benjamin Snow's resume into MongoDB with additional fields
# Inserted John Nelson's resume into MongoDB with additional fields
# Inserted Mackenzie Dyer's resume into MongoDB with additional fields
# Inserted Jacob Ramirez's resume into MongoDB with additional fields
# Inserted Jeffery Robertson's resume into MongoDB with additional fields
# Inserted Devin Mccarthy's resume into MongoDB with additional fields
# Inserted Cody Torres's resume into MongoDB with additional fields
# Inserted Virginia Miller's resume into MongoDB with additional fields
# Inserted Christopher Lee's resume into MongoDB with additional fields
# Inserted Alison Rodriguez's resume into MongoDB with additional fields
# Inserted Molly Bates's resume into MongoDB with additional fields
# Inserted Benjamin Allen's resume into MongoDB with additional fields
# Inserted Traci Spencer's resume into MongoDB with additional fields
# Inserted Karen Reyes's resume into MongoDB with additional fields
# Inserted Derek Watson's resume into MongoDB with additional fields
# Inserted John May's resume into MongoDB with additional fields
# Inserted Jennifer Mcdowell's resume into MongoDB with additional fields
# Inserted Richard Shepard's resume into MongoDB with additional fields
# Inserted Ryan Higgins's resume into MongoDB with additional fields
# Inserted Christopher Casey's resume into MongoDB with additional fields
# Inserted Allison Coleman's resume into MongoDB with additional fields
# Inserted Lauren Wilson's resume into MongoDB with additional fields
# Inserted Patricia Vazquez's resume into MongoDB with additional fields
# Inserted David Howard's resume into MongoDB with additional fields
# Inserted Mackenzie Cruz's resume into MongoDB with additional fields
# Inserted Mrs. Savannah Roberson's resume into MongoDB with additional fields
# Inserted Ms. Lauren Mathews's resume into MongoDB with additional fields
# Inserted Jeremy Mccormick's resume into MongoDB with additional fields
# Inserted Helen Brown's resume into MongoDB with additional fields
# Inserted Laura Johnson's resume into MongoDB with additional fields
# Inserted Charles Malone's resume into MongoDB with additional fields
# Inserted Ruth Conley's resume into MongoDB with additional fields
# Inserted Paul Webb's resume into MongoDB with additional fields
# Inserted Keith Anderson's resume into MongoDB with additional fields
# Inserted Steven Reed's resume into MongoDB with additional fields
# Inserted Jennifer Thompson's resume into MongoDB with additional fields
# Inserted Dennis Ford's resume into MongoDB with additional fields
# Inserted Carrie Patton's resume into MongoDB with additional fields
# Inserted Shelby Wu's resume into MongoDB with additional fields
# Inserted Danielle Wong's resume into MongoDB with additional fields
# Inserted Tanner Johnson's resume into MongoDB with additional fields
# Inserted Amanda Gardner's resume into MongoDB with additional fields
# Inserted Stephen Carroll's resume into MongoDB with additional fields
# Inserted Brandon Sellers's resume into MongoDB with additional fields
# Inserted Miss April Bell's resume into MongoDB with additional fields
# Inserted Jo Sparks's resume into MongoDB with additional fields
# Inserted Karen Holloway's resume into MongoDB with additional fields
# Inserted Robert Foster's resume into MongoDB with additional fields
# Inserted Jaime Clayton's resume into MongoDB with additional fields
# Inserted Tracy Maldonado's resume into MongoDB with additional fields
# Inserted Eddie Garrett's resume into MongoDB with additional fields
# Inserted Sabrina Rodriguez's resume into MongoDB with additional fields
# Inserted Tammy Winters's resume into MongoDB with additional fields
# Inserted Robin Kennedy's resume into MongoDB with additional fields
# Inserted Carly Hamilton DDS's resume into MongoDB with additional fields
# Inserted Kim Gonzalez's resume into MongoDB with additional fields
# Inserted Jeremy Brown's resume into MongoDB with additional fields
# Inserted Lauren Watson's resume into MongoDB with additional fields
# Inserted Savannah Rice's resume into MongoDB with additional fields
# Inserted Jasmine Knight's resume into MongoDB with additional fields
# Inserted Brian Kelley's resume into MongoDB with additional fields
# Inserted Michael Everett's resume into MongoDB with additional fields
# Inserted Veronica Cline's resume into MongoDB with additional fields
# Inserted Aaron Moore's resume into MongoDB with additional fields
# Inserted Brooke Lopez's resume into MongoDB with additional fields
# Inserted Amanda Mccann's resume into MongoDB with additional fields
# Inserted Brittany Barron's resume into MongoDB with additional fields
# Inserted Nicholas Williams's resume into MongoDB with additional fields
# Inserted Steven Garcia's resume into MongoDB with additional fields
# Inserted Mark Prince's resume into MongoDB with additional fields
# Inserted Ashley Nelson's resume into MongoDB with additional fields
# Inserted Michelle Lopez's resume into MongoDB with additional fields
# Inserted Sharon Anderson's resume into MongoDB with additional fields
# Inserted Tonya Hooper's resume into MongoDB with additional fields
# Inserted Lisa Rhodes's resume into MongoDB with additional fields
# Inserted Stephanie Hunt PhD's resume into MongoDB with additional fields
# Inserted John Jennings's resume into MongoDB with additional fields
# Inserted Casey Brady's resume into MongoDB with additional fields
# Inserted Angela Adkins's resume into MongoDB with additional fields
# Inserted Brian Drake's resume into MongoDB with additional fields
# Inserted Samantha Carter's resume into MongoDB with additional fields
# Inserted Christopher Simon's resume into MongoDB with additional fields
# Inserted Jennifer Wang's resume into MongoDB with additional fields
# Inserted Tiffany Howard's resume into MongoDB with additional fields
# Inserted Amanda Jimenez's resume into MongoDB with additional fields
# Inserted Robert Thompson's resume into MongoDB with additional fields
# Inserted Rachel Pratt's resume into MongoDB with additional fields
# Inserted Pamela Brown's resume into MongoDB with additional fields
# Inserted David Oconnell's resume into MongoDB with additional fields
# Inserted Nicholas Key's resume into MongoDB with additional fields
# Inserted Erica Cardenas's resume into MongoDB with additional fields
# Inserted Jennifer Marshall's resume into MongoDB with additional fields
# Inserted Virginia Cooper's resume into MongoDB with additional fields
# Inserted Nicholas Smith's resume into MongoDB with additional fields
# Inserted Ms. Michelle Willis's resume into MongoDB with additional fields
# All resumes have been processed and inserted into MongoDB with additional fields.

# %%
import os
import base64
import pandas as pd
from pymongo import MongoClient
from faker import Faker
import random
from bs4 import BeautifulSoup

fake = Faker()

client = MongoClient('mongodb://localhost:27017/')
db = client['AI-RECRUITMENT']
company_name = 'Compnay 1'
collection = db[company_name]


def generate_users(count):
    users = []
    for i in range(count):
        name = fake.name()
        data = {

            'id': fake.numerify(text='####'),
            'name': name,
            'email': company_name.lower().replace(" ",".") + '@' + company_name.lower().replace(" ","-") + ".com",
            'phone': fake.phone_number(),
            'role': 'Hiring Manager',
            'company': company_name
        }
        users.append(data)

    return users

def main():
    users = generate_users(50)

    collection.insert_many(users)
    
    print('Data inserted successfully')

if __name__ == '__main__':
    main()
# Out:
# Data inserted successfully

# %%
"""
Code to insert the jobs into the database
job dataset used : https://www.kaggle.com/datasets/ravindrasinghrana/job-description-dataset
"""


import pandas as pd
from pymongo import MongoClient

file_path = '/Users/sakshigupta/Desktop/FYP/AI-RecruitmentTool/back-end/job_descriptions.csv'  
df = pd.read_csv(file_path)

client = MongoClient('mongodb://localhost:27017/')
db = client['AI-RECRUITMENT']
collection = db['JOBS']

# print(df[0])

# Insert each row in the DataFrame as a document in MongoDB
for index, row in df.iterrows():
    # Convert the row to a dictionary
    data = row.to_dict()
    # Insert the dictionary into MongoDB
    collection.insert_one(data)
    print(f'Inserted row {index}')

print('All rows inserted')
# Out:
# Inserted row 0
# Inserted row 1
# Inserted row 2
# Inserted row 3
# Inserted row 4
# Inserted row 5
# Inserted row 6
# Inserted row 7
# Inserted row 8
# Inserted row 9
# Inserted row 10
# Inserted row 11
# Inserted row 12
# Inserted row 13
# Inserted row 14
# Inserted row 15
# Inserted row 16
# Inserted row 17
# Inserted row 18
# Inserted row 19
# Inserted row 20
# Inserted row 21
# Inserted row 22
# Inserted row 23
# Inserted row 24
# Inserted row 25
# Inserted row 26
# Inserted row 27
# Inserted row 28
# Inserted row 29
# Inserted row 30
# Inserted row 31
# Inserted row 32
# Inserted row 33
# Inserted row 34
# Inserted row 35
# Inserted row 36
# Inserted row 37
# Inserted row 38
# Inserted row 39
# Inserted row 40
# Inserted row 41
# Inserted row 42
# Inserted row 43
# Inserted row 44
# Inserted row 45
# Inserted row 46
# Inserted row 47
# Inserted row 48
# Inserted row 49
# Inserted row 50
# Inserted row 51
# Inserted row 52
# Inserted row 53
# Inserted row 54
# Inserted row 55
# Inserted row 56
# Inserted row 57
# Inserted row 58
# Inserted row 59
# Inserted row 60
# Inserted row 61
# Inserted row 62
# Inserted row 63
# Inserted row 64
# Inserted row 65
# Inserted row 66
# Inserted row 67
# Inserted row 68
# Inserted row 69
# Inserted row 70
# Inserted row 71
# Inserted row 72
# Inserted row 73
# Inserted row 74
# Inserted row 75
# Inserted row 76
# Inserted row 77
# Inserted row 78
# Inserted row 79
# Inserted row 80
# Inserted row 81
# Inserted row 82
# Inserted row 83
# Inserted row 84
# Inserted row 425
# Inserted row 426
# Inserted row 427
# Inserted row 428
# Inserted row 429
# Inserted row 430
# Inserted row 431
# Inserted row 432
# Inserted row 433
# Inserted row 434
# Inserted row 435
# Inserted row 436
# Inserted row 437
# Inserted row 438
# Inserted row 439
# Inserted row 440
# Inserted row 441
# Inserted row 442
# Inserted row 443
# Inserted row 444
# Inserted row 445
# Inserted row 446
# Inserted row 447
# Inserted row 448
# Inserted row 449
# Inserted row 450
# Inserted row 451
# Inserted row 452
# Inserted row 453
# Inserted row 454
# Inserted row 455
# Inserted row 456
# Inserted row 457
# Inserted row 458
# Inserted row 459
# Inserted row 460
# Inserted row 461
# Inserted row 462
# Inserted row 463
# Inserted row 464
# Inserted row 465
# Inserted row 466
# Inserted row 467
# Inserted row 468
# Inserted row 469
# Inserted row 470
# Inserted row 471
# Inserted row 472
# Inserted row 473
# Inserted row 474
# Inserted row 475
# Inserted row 476
# Inserted row 477
# Inserted row 478
# Inserted row 479
# Inserted row 480
# Inserted row 481
# Inserted row 482
# Inserted row 483
# Inserted row 484
# Inserted row 485
# Inserted row 486
# Inserted row 487
# Inserted row 488
# Inserted row 489
# Inserted row 490
# Inserted row 491
# Inserted row 492
# Inserted row 493
# Inserted row 494
# Inserted row 495
# Inserted row 496
# Inserted row 497
# Inserted row 498
# Inserted row 499
# Inserted row 500
# Inserted row 501
# Inserted row 502
# Inserted row 503
# Inserted row 504
# Inserted row 505
# Inserted row 506
# Inserted row 507
# Inserted row 508
# Inserted row 509
# Inserted row 510
# Inserted row 511
# Inserted row 512
# Inserted row 513
# Inserted row 514
# Inserted row 515
# Inserted row 516
# Inserted row 517
# Inserted row 518
# Inserted row 519
# Inserted row 520
# Inserted row 521
# Inserted row 522
# Inserted row 523
# Inserted row 524
# Inserted row 525
# Inserted row 526
# Inserted row 527
# Inserted row 528
# Inserted row 529
# Inserted row 530
# Inserted row 531
# Inserted row 532
# Inserted row 533
# Inserted row 534
# Inserted row 535
# Inserted row 536
# Inserted row 537
# Inserted row 538
# Inserted row 539
# Inserted row 540
# Inserted row 541
# Inserted row 542
# Inserted row 543
# Inserted row 544
# Inserted row 545
# Inserted row 546
# Inserted row 547
# Inserted row 548
# Inserted row 549
# Inserted row 550
# Inserted row 551
# Inserted row 552
# Inserted row 553
# Inserted row 554
# Inserted row 555
# Inserted row 556
# Inserted row 557
# Inserted row 558
# Inserted row 559
# Inserted row 560
# Inserted row 561
# Inserted row 562
# Inserted row 563
# Inserted row 564
# Inserted row 565
# Inserted row 566
# Inserted row 567
# Inserted row 568
# Inserted row 569
# Inserted row 570
# Inserted row 571
# Inserted row 572
# Inserted row 573
# Inserted row 574
# Inserted row 575
# Inserted row 576
# Inserted row 577
# Inserted row 578
# Inserted row 579
# Inserted row 580
# Inserted row 581
# Inserted row 582
# Inserted row 583
# Inserted row 584
# Inserted row 585
# Inserted row 586
# Inserted row 587
# Inserted row 588
# Inserted row 589
# Inserted row 590
# Inserted row 591
# Inserted row 592
# Inserted row 593
# Inserted row 594
# Inserted row 765
# Inserted row 766
# Inserted row 767
# Inserted row 768
# Inserted row 769
# Inserted row 770
# Inserted row 771
# Inserted row 772
# Inserted row 773
# Inserted row 774
# Inserted row 775
# Inserted row 776
# Inserted row 777
# Inserted row 778
# Inserted row 779
# Inserted row 780
# Inserted row 781
# Inserted row 782
# Inserted row 783
# Inserted row 784
# Inserted row 785
# Inserted row 786
# Inserted row 787
# Inserted row 788
# Inserted row 789
# Inserted row 790
# Inserted row 791
# Inserted row 792
# Inserted row 793
# Inserted row 794
# Inserted row 795
# Inserted row 796
# Inserted row 797
# Inserted row 798
# Inserted row 799
# Inserted row 800
# Inserted row 801
# Inserted row 802
# Inserted row 803
# Inserted row 804
# Inserted row 805
# Inserted row 806
# Inserted row 807
# Inserted row 808
# Inserted row 809
# Inserted row 810
# Inserted row 811
# Inserted row 812
# Inserted row 813
# Inserted row 814
# Inserted row 815
# Inserted row 816
# Inserted row 817
# Inserted row 818
# Inserted row 819
# Inserted row 820
# Inserted row 821
# Inserted row 822
# Inserted row 823
# Inserted row 824
# Inserted row 825
# Inserted row 826
# Inserted row 827
# Inserted row 828
# Inserted row 829
# Inserted row 830
# Inserted row 831
# Inserted row 832
# Inserted row 833
# Inserted row 834
# Inserted row 835
# Inserted row 836
# Inserted row 837
# Inserted row 838
# Inserted row 839
# Inserted row 840
# Inserted row 841
# Inserted row 842
# Inserted row 843
# Inserted row 844
# Inserted row 845
# Inserted row 846
# Inserted row 847
# Inserted row 848
# Inserted row 849
# Inserted row 850
# Inserted row 851
# Inserted row 852
# Inserted row 853
# Inserted row 854
# Inserted row 855
# Inserted row 856
# Inserted row 857
# Inserted row 858
# Inserted row 859
# Inserted row 860
# Inserted row 861
# Inserted row 862
# Inserted row 863
# Inserted row 864
# Inserted row 865
# Inserted row 866
# Inserted row 867
# Inserted row 868
# Inserted row 869
# Inserted row 870
# Inserted row 871
# Inserted row 872
# Inserted row 873
# Inserted row 874
# Inserted row 875
# Inserted row 876
# Inserted row 877
# Inserted row 878
# Inserted row 879
# Inserted row 880
# Inserted row 881
# Inserted row 882
# Inserted row 883
# Inserted row 884
# Inserted row 885
# Inserted row 886
# Inserted row 887
# Inserted row 888
# Inserted row 889
# Inserted row 890
# Inserted row 891
# Inserted row 892
# Inserted row 893
# Inserted row 894
# Inserted row 895
# Inserted row 896
# Inserted row 897
# Inserted row 898
# Inserted row 899
# Inserted row 900
# Inserted row 901
# Inserted row 902
# Inserted row 903
# Inserted row 904
# Inserted row 905
# Inserted row 906
# Inserted row 907
# Inserted row 908
# Inserted row 909
# Inserted row 910
# Inserted row 911
# Inserted row 912
# Inserted row 913
# Inserted row 914
# Inserted row 915
# Inserted row 916
# Inserted row 917
# Inserted row 918
# Inserted row 919
# Inserted row 920
# Inserted row 921
# Inserted row 922
# Inserted row 923
# Inserted row 924
# Inserted row 925
# Inserted row 926
# Inserted row 927
# Inserted row 928
# Inserted row 929
# Inserted row 930
# Inserted row 931
# Inserted row 932
# Inserted row 933
# Inserted row 934
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 24
#      22     data = row.to_dict()
#      23     # Insert the dictionary into MongoDB
# ---> 24     collection.insert_one(data)
#      25     print(f'Inserted row {index}')
#      27 print('All rows inserted')
#
# File ~/anaconda3/envs/fyp_project/lib/python3.12/site-packages/pymongo/collection.py:658, in Collection.insert_one(self, document, bypass_document_validation, session, comment)
#     654     document["_id"] = ObjectId()  # type: ignore[index]
#     656 write_concern = self._write_concern_for(session)
#     657 return InsertOneResult(
# --> 658     self._insert_one(
#     659         document,
#     660         ordered=True,
#     661         write_concern=write_concern,
#     662         op_id=None,
#     663         bypass_doc_val=bypass_document_validation,
#     664         session=session,
#     665         comment=comment,
#     666     ),
#     667     write_concern.acknowledged,
#     668 )
#
# File ~/anaconda3/envs/fyp_project/lib/python3.12/site-packages/pymongo/collection.py:598, in Collection._insert_one(self, doc, ordered, write_concern, op_id, bypass_doc_val, session, comment)
#     586     result = conn.command(
#     587         self.__database.name,
#     588         command,
#    (...)
#     593         retryable_write=retryable_write,
#     594     )
#     596     _check_write_command_response(result)
# --> 598 self.__database.client._retryable_write(
#     599     acknowledged, _insert_command, session, operation=_Op.INSERT
#     600 )
#     602 if not isinstance(doc, RawBSONDocument):
#     603     return doc.get("_id")
#
# File ~/anaconda3/envs/fyp_project/lib/python3.12/site-packages/pymongo/mongo_client.py:1575, in MongoClient._retryable_write(self, retryable, func, session, operation, bulk, operation_id)
#    1561 """Execute an operation with consecutive retries if possible
#    1562
#    1563 Returns func()'s return value on success. On error retries the same
#    (...)
#    1572 :param bulk: bulk abstraction to execute operations in bulk, defaults to None
#    1573 """
#    1574 with self._tmp_session(session) as s:
# -> 1575     return self._retry_with_session(retryable, func, s, bulk, operation, operation_id)
#
# File ~/anaconda3/envs/fyp_project/lib/python3.12/site-packages/pymongo/mongo_client.py:1461, in MongoClient._retry_with_session(self, retryable, func, session, bulk, operation, operation_id)
#    1456 # Ensure that the options supports retry_writes and there is a valid session not in
#    1457 # transaction, otherwise, we will not support retry behavior for this txn.
#    1458 retryable = bool(
#    1459     retryable and self.options.retry_writes and session and not session.in_transaction
#    1460 )
# -> 1461 return self._retry_internal(
#    1462     func=func,
#    1463     session=session,
#    1464     bulk=bulk,
#    1465     operation=operation,
#    1466     retryable=retryable,
#    1467     operation_id=operation_id,
#    1468 )
#
# File ~/anaconda3/envs/fyp_project/lib/python3.12/site-packages/pymongo/_csot.py:108, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     106         with _TimeoutContext(timeout):
#     107             return func(self, *args, **kwargs)
# --> 108 return func(self, *args, **kwargs)
#
# File ~/anaconda3/envs/fyp_project/lib/python3.12/site-packages/pymongo/mongo_client.py:1507, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1470 @_csot.apply
#    1471 def _retry_internal(
#    1472     self,
#    (...)
#    1481     operation_id: Optional[int] = None,
#    1482 ) -> T:
#    1483     """Internal retryable helper for all client transactions.
#    1484
#    1485     :param func: Callback function we want to retry
#    (...)
#    1494     :return: Output of the calling func()
#    1495     """
#    1496     return _ClientConnectionRetryable(
#    1497         mongo_client=self,
#    1498         func=func,
#    1499         bulk=bulk,
#    1500         operation=operation,
#    1501         is_read=is_read,
#    1502         session=session,
#    1503         read_pref=read_pref,
#    1504         address=address,
#    1505         retryable=retryable,
#    1506         operation_id=operation_id,
# -> 1507     ).run()
#
# File ~/anaconda3/envs/fyp_project/lib/python3.12/site-packages/pymongo/mongo_client.py:2353, in _ClientConnectionRetryable.run(self)
#    2351 self._check_last_error(check_csot=True)
#    2352 try:
# -> 2353     return self._read() if self._is_read else self._write()
#    2354 except ServerSelectionTimeoutError:
#    2355     # The application may think the write was never attempted
#    2356     # if we raise ServerSelectionTimeoutError on the retry
#    2357     # attempt. Raise the original exception instead.
#    2358     self._check_last_error()
#
# File ~/anaconda3/envs/fyp_project/lib/python3.12/site-packages/pymongo/mongo_client.py:2470, in _ClientConnectionRetryable._write(self)
#    2468             self._check_last_error()
#    2469             self._retryable = False
# -> 2470         return self._func(self._session, conn, self._retryable)  # type: ignore
#    2471 except PyMongoError as exc:
#    2472     if not self._retryable:
#
# File ~/anaconda3/envs/fyp_project/lib/python3.12/site-packages/pymongo/collection.py:586, in Collection._insert_one.<locals>._insert_command(session, conn, retryable_write)
#     583 if bypass_doc_val:
#     584     command["bypassDocumentValidation"] = True
# --> 586 result = conn.command(
#     587     self.__database.name,
#     588     command,
#     589     write_concern=write_concern,
#     590     codec_options=self.__write_response_codec_options,
#     591     session=session,
#     592     client=self.__database.client,
#     593     retryable_write=retryable_write,
#     594 )
#     596 _check_write_command_response(result)
#
# File ~/anaconda3/envs/fyp_project/lib/python3.12/site-packages/pymongo/helpers.py:342, in _handle_reauth.<locals>.inner(*args, **kwargs)
#     339 from pymongo.pool import Connection
#     341 try:
# --> 342     return func(*args, **kwargs)
#     343 except OperationFailure as exc:
#     344     if no_reauth:
#
# File ~/anaconda3/envs/fyp_project/lib/python3.12/site-packages/pymongo/pool.py:1017, in Connection.command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#    1015 # Catch socket.error, KeyboardInterrupt, etc. and close ourselves.
#    1016 except BaseException as error:
# -> 1017     self._raise_connection_failure(error)
#
# File ~/anaconda3/envs/fyp_project/lib/python3.12/site-packages/pymongo/pool.py:989, in Connection.command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     987     self._raise_if_not_writable(unacknowledged)
#     988 try:
# --> 989     return command(
#     990         self,
#     991         dbname,
#     992         spec,
#     993         self.is_mongos,
#     994         read_preference,
#     995         codec_options,
#     996         session,
#     997         client,
#     998         check,
#     999         allowable_errors,
#    1000         self.address,
#    1001         listeners,
#    1002         self.max_bson_size,
#    1003         read_concern,
#    1004         parse_write_concern_error=parse_write_concern_error,
#    1005         collation=collation,
#    1006         compression_ctx=self.compression_context,
#    1007         use_op_msg=self.op_msg_enabled,
#    1008         unacknowledged=unacknowledged,
#    1009         user_fields=user_fields,
#    1010         exhaust_allowed=exhaust_allowed,
#    1011         write_concern=write_concern,
#    1012     )
#    1013 except (OperationFailure, NotPrimaryError):
#    1014     raise
#
# File ~/anaconda3/envs/fyp_project/lib/python3.12/site-packages/pymongo/network.py:202, in command(conn, dbname, spec, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed, write_concern)
#     200     response_doc: _DocumentOut = {"ok": 1}
#     201 else:
# --> 202     reply = receive_message(conn, request_id)
#     203     conn.more_to_come = reply.more_to_come
#     204     unpacked_docs = reply.unpack_response(
#     205         codec_options=codec_options, user_fields=user_fields
#     206     )
#
# File ~/anaconda3/envs/fyp_project/lib/python3.12/site-packages/pymongo/network.py:337, in receive_message(conn, request_id, max_message_size)
#     335     data = decompress(_receive_data_on_socket(conn, length - 25, deadline), compressor_id)
#     336 else:
# --> 337     data = _receive_data_on_socket(conn, length - 16, deadline)
#     339 try:
#     340     unpack_reply = _UNPACK_REPLY[op_code]
#
# File ~/anaconda3/envs/fyp_project/lib/python3.12/site-packages/pymongo/network.py:390, in _receive_data_on_socket(conn, length, deadline)
#     388 def _receive_data_on_socket(conn: Connection, length: int, deadline: Optional[float]) -> memoryview:
#     389     buf = bytearray(length)
# --> 390     mv = memoryview(buf)
#     391     bytes_read = 0
#     392     while bytes_read < length:
#
# KeyboardInterrupt:
